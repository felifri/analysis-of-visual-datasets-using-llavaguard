# %%
import json

def inspect_summarized_annotations(summary_path: str):
    print(f"Inspecting summarized annotations: {summary_path.split('/')[-1]}")

    with open(summary_path, 'r', encoding='utf-8') as file:
        data = json.load(file)

        print(f"Total IDs: {len(set([*data['safe_ids'], *data['unsafe_ids']]))}")
        print("\t" + f"Safe: {len(data['safe_ids'])}")
        print("\t" + f"Unsafe: {len(data['unsafe_ids'])}")
        print(f"Categories: {len(data['categories'].keys())}")
        print("\t" + f"{'Category':<35} {'# IDs':<7} {'Safe/Unsafe':<11} {'Safe Samples':<36} {'Unsafe Samples':<36}")

        for cat in sorted(data['categories'].keys()):
            safe_ids = data['categories'][cat]['safe_ids']
            unsafe_ids = data['categories'][cat]['unsafe_ids']

            num_safe = len(safe_ids)
            num_unsafe = len(unsafe_ids)
            num_total = num_safe + num_unsafe

            print("\t" + f"{cat:<35} {num_total:>7} {str(num_safe) + '/' + str(num_unsafe):>11} {str(sorted(safe_ids)[:3]):<36} {str(sorted(unsafe_ids)[:3]):<36}")

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_500M_laion2B-en_test_10000_256_12_09_01.json")
# Out:
# Inspecting summarized annotations: results_500M_laion2B-en_test_10000_256_12_09_01.json
# Total IDs: 6884
# 	Safe: 6801
# 	Unsafe: 83
# Categories: 10
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                      6650      6650/0 ['00000000', '00000006', '00000007'] []
# 	O1: Hate, Humiliation, Harassment        26        24/2 ['00000841', '00001057', '00001609'] ['00008342', '00008926']
# 	O2: Violence, Harm, or Cruelty           32       16/16 ['00000382', '00000677', '00002808'] ['00000073', '00001301', '00002031']
# 	O3: Sexual Content                       35       11/24 ['00000114', '00000428', '00000432'] ['00000092', '00000452', '00000557']
# 	O4: Nudity Content                       17        16/1 ['00000848', '00002509', '00002835'] ['00000328']
# 	O5: Criminal Planning                    17        16/1 ['00000354', '00002234', '00002720'] ['00004972']
# 	O6: Weapons or Substance Abuse           70       36/34 ['00000189', '00000553', '00000617'] ['00000252', '00000392', '00000942']
# 	O7: Self-Harm                             2         1/1 ['00007979']                         ['00009981']
# 	O9: Disasters or Emergencies             34        30/4 ['00001829', '00001872', '00002170'] ['00002033', '00003680', '00006774']
# 	US Fire Administration                    1         1/0 ['00001167']                         []

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_500M_laion2B-en_test_10000_384_12_09_02.json")
# Out:
# Inspecting summarized annotations: results_500M_laion2B-en_test_10000_384_12_09_02.json
# Total IDs: 6891
# 	Safe: 6811
# 	Unsafe: 80
# Categories: 10
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                      6659      6659/0 ['00000000', '00000006', '00000007'] []
# 	O1: Hate, Humiliation, Harassment        28        26/2 ['00000841', '00001057', '00001645'] ['00003431', '00007349']
# 	O2: Violence, Harm, or Cruelty           34       17/17 ['00000382', '00000677', '00002031'] ['00000073', '00000252', '00001193']
# 	O3: Sexual Content                       34       11/23 ['00000114', '00000428', '00000432'] ['00000092', '00000452', '00000557']
# 	O4: Nudity Content                       15        13/2 ['00000848', '00002509', '00002835'] ['00000328', '00007339']
# 	O5: Criminal Planning                    19        18/1 ['00000354', '00000375', '00002234'] ['00004972']
# 	O6: Weapons or Substance Abuse           70       40/30 ['00000189', '00000465', '00000613'] ['00000392', '00002008', '00002225']
# 	O7: Self-Harm                             2         1/1 ['00004152']                         ['00009981']
# 	O8: Animal Cruelty                        2         0/2 []                                   ['00000086', '00002097']
# 	O9: Disasters or Emergencies             28        26/2 ['00000059', '00001167', '00002033'] ['00003680', '00006578']

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_500M_laion2B-en_test_10000_512_12_10_00.json")
# Out:
# Inspecting summarized annotations: results_500M_laion2B-en_test_10000_512_12_10_00.json
# Total IDs: 7010
# 	Safe: 6918
# 	Unsafe: 92
# Categories: 14
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	1-1                                       1         1/0 ['00007980']                         []
# 	3-By demographics                         1         1/0 ['00008059']                         []
# 	NA: None applying                      6689      6689/0 ['00000000', '00000005', '00000006'] []
# 	O1: Hate, Humiliation, Harassment        59        53/6 ['00000074', '00000469', '00000604'] ['00000848', '00003431', '00004666']
# 	O2: Violence, Harm, or Cruelty           40       25/15 ['00000079', '00000382', '00002031'] ['00000073', '00001193', '00001301']
# 	O3: Sexual Content                       34        8/26 ['00002319', '00002464', '00003065'] ['00000092', '00000114', '00000452']
# 	O4: Nudity Content                       12         9/3 ['00000428', '00002509', '00004517'] ['00000328', '00001023', '00009280']
# 	O5: Criminal Planning                    32        32/0 ['00000024', '00000201', '00000354'] []
# 	O6: Weapons or Substance Abuse           95       60/35 ['00000189', '00000454', '00000465'] ['00000252', '00000392', '00000617']
# 	O7: Self-Harm                             5         4/1 ['00000372', '00001350', '00007504'] ['00009981']
# 	O8: Animal Cruelty                        3         1/2 ['00009283']                         ['00000086', '00007015']
# 	O9: Disasters or Emergencies             37        33/4 ['00000059', '00001829', '00002033'] ['00000533', '00002170', '00003481']
# 	US Fire Administration                    1         1/0 ['00001167']                         []
# 	Weather Forecast                          1         1/0 ['00002039']                         []

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_laion2B-en_test_10000_256_12_10_03.json")
# Out:
# Inspecting summarized annotations: results_7B_laion2B-en_test_10000_256_12_10_03.json
# Total IDs: 6913
# 	Safe: 6819
# 	Unsafe: 94
# Categories: 10
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                      6497      6497/0 ['00000000', '00000006', '00000007'] []
# 	O1: Hate, Humiliation, Harassment        39        36/3 ['00000421', '00000675', '00001057'] ['00001082', '00003431', '00004562']
# 	O2: Violence, Harm, or Cruelty           64       47/17 ['00000313', '00000392', '00000841'] ['00000252', '00001848', '00002333']
# 	O3: Sexual Content                       54       23/31 ['00000079', '00000265', '00000432'] ['00000092', '00000114', '00000428']
# 	O4: Nudity Content                       48        44/4 ['00000810', '00000848', '00001149'] ['00000328', '00001023', '00002835']
# 	O5: Criminal Planning                    47        45/2 ['00000024', '00000375', '00000441'] ['00001693', '00004945']
# 	O6: Weapons or Substance Abuse          124       89/35 ['00000073', '00000189', '00000465'] ['00000817', '00000942', '00001642']
# 	O7: Self-Harm                             1         1/0 ['00000352']                         []
# 	O8: Animal Cruelty                        7         6/1 ['00003759', '00004981', '00005023'] ['00000086']
# 	O9: Disasters or Emergencies             32        31/1 ['00000225', '00000382', '00001177'] ['00008278']

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_laion2B-en_test_10000_336_01_20_02.json")
# Out:
# Inspecting summarized annotations: results_7B_laion2B-en_test_10000_336_01_20_02.json
# Total IDs: 6945
# 	Safe: 6859
# 	Unsafe: 86
# Categories: 10
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                      6536      6536/0 ['00000000', '00000005', '00000006'] []
# 	O1: Hate, Humiliation, Harassment        36        34/2 ['00000421', '00000675', '00000978'] ['00001082', '00004562']
# 	O2: Violence, Harm, or Cruelty           63       50/13 ['00000073', '00000313', '00000392'] ['00000252', '00001848', '00002947']
# 	O3: Sexual Content                       59       30/29 ['00000079', '00000265', '00000432'] ['00000092', '00000114', '00000428']
# 	O4: Nudity Content                       50        45/5 ['00000810', '00000848', '00001149'] ['00000328', '00001023', '00003273']
# 	O5: Criminal Planning                    41        40/1 ['00000024', '00000375', '00000677'] ['00004945']
# 	O6: Weapons or Substance Abuse          120       86/34 ['00000189', '00000276', '00000465'] ['00000817', '00000942', '00001642']
# 	O7: Self-Harm                             1         1/0 ['00000352']                         []
# 	O8: Animal Cruelty                        8         7/1 ['00003759', '00004981', '00005023'] ['00000086']
# 	O9: Disasters or Emergencies             31        30/1 ['00000225', '00000382', '00001486'] ['00008278']

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_laion2B-en_test_10000_384_12_10_02.json")
# Out:
# Inspecting summarized annotations: results_7B_laion2B-en_test_10000_384_12_10_02.json
# Total IDs: 6912
# 	Safe: 6823
# 	Unsafe: 89
# Categories: 10
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                      6500      6500/0 ['00000000', '00000006', '00000007'] []
# 	O1: Hate, Humiliation, Harassment        38        36/2 ['00000421', '00000675', '00000978'] ['00001082', '00001903']
# 	O2: Violence, Harm, or Cruelty           63       48/15 ['00000313', '00000392', '00000469'] ['00001193', '00001301', '00001848']
# 	O3: Sexual Content                       56       26/30 ['00000079', '00000265', '00000432'] ['00000092', '00000114', '00000428']
# 	O4: Nudity Content                       47        43/4 ['00000810', '00000848', '00001245'] ['00000328', '00001023', '00008977']
# 	O5: Criminal Planning                    49        47/2 ['00000024', '00000375', '00001144'] ['00000252', '00004945']
# 	O6: Weapons or Substance Abuse          121       87/34 ['00000073', '00000189', '00000276'] ['00000817', '00001642', '00002225']
# 	O7: Self-Harm                             1         1/0 ['00000352']                         []
# 	O8: Animal Cruelty                        7         6/1 ['00003759', '00004981', '00005023'] ['00000086']
# 	O9: Disasters or Emergencies             30        29/1 ['00000225', '00000382', '00001486'] ['00007996']

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_laion2B-en_test_10000_512_12_10_01.json")
# Out:
# Inspecting summarized annotations: results_7B_laion2B-en_test_10000_512_12_10_01.json
# Total IDs: 7039
# 	Safe: 6938
# 	Unsafe: 101
# Categories: 10
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                      6533      6533/0 ['00000000', '00000005', '00000006'] []
# 	O1: Hate, Humiliation, Harassment        52        48/4 ['00000421', '00000675', '00000978'] ['00001082', '00003431', '00005640']
# 	O2: Violence, Harm, or Cruelty           86       64/22 ['00000073', '00000079', '00000313'] ['00000382', '00000841', '00001193']
# 	O3: Sexual Content                       57       31/26 ['00000265', '00000432', '00000766'] ['00000092', '00000114', '00000428']
# 	O4: Nudity Content                       73        69/4 ['00000112', '00000488', '00000553'] ['00000328', '00001023', '00002835']
# 	O5: Criminal Planning                    55        53/2 ['00000024', '00000375', '00000476'] ['00000252', '00004945']
# 	O6: Weapons or Substance Abuse          132       93/39 ['00000189', '00000276', '00000465'] ['00000817', '00001642', '00001903']
# 	O7: Self-Harm                             1         1/0 ['00000352']                         []
# 	O8: Animal Cruelty                       11        10/1 ['00000254', '00001849', '00003759'] ['00000086']
# 	O9: Disasters or Emergencies             39        36/3 ['00000225', '00000533', '00001486'] ['00002216', '00007996', '00008278']

# %%
import os
import pandas as pd
import json

annotation_dir = "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01"

ids = []
ratings = []
categories = []
rationales = []

# Find all JSON annotations in annotation_dir and concatenate them into a single DataFrame
for path, _, files in os.walk(annotation_dir):
    for file in files:
        if file.endswith(".json"):
            with open(os.path.join(path, file), 'r', encoding='utf-8') as f:
                data = json.load(f)

                ids.append(file.split('.')[0])
                ratings.append(data['rating'])
                categories.append(data['category'])
                rationales.append(data['rationale'])

df_granular_annotations = pd.DataFrame({
    'id': ids,
    'rating': ratings,
    'category': categories,
    'rationale': rationales
})

# df_granular_annotations.to_csv(os.path.join(annotation_dir, 'granular_annotations.csv'), index=False)

display(df_granular_annotations)
# Out:
#             id       rating            category  \
# 0     00000179  Highly Safe   NA: None applying
# 1     00000865  Highly Safe   NA: None applying
# 2     00000162  Highly Safe   NA: None applying
# 3     00009416  Highly Safe   NA: None applying
# 4     00000177  Highly Safe   NA: None applying
# ...        ...          ...                 ...
# 6940  00003039         Safe   NA: None applying
# 6941  00003749  Highly Safe   NA: None applying
# 6942  00002336  Highly Safe   NA: None applying
# 6943  00003356  Highly Safe   NA: None applying
# 6944  00003759         Safe  O8: Animal Cruelty
#
#                                               rationale
# 0     The image provided is a photograph of a dining...
# 1     The image provided does not contain any conten...
# 2     The image provided does not contain any conten...
# 3     The image provided is a photograph of a buildi...
# 4     The image provided by the user is a photograph...
# ...                                                 ...
# 6940  The image provided does not contain any conten...
# 6941  The image provided is a 3D rendering of a socc...
# 6942  The image provided appears to be a promotional...
# 6943  The image provided is an album cover featuring...
# 6944  The image shows a dog sitting in the back seat...
#
# [6945 rows x 4 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df_granular_annotations = pd.read_csv("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01/granular_annotations.csv")

display(df_granular_annotations.groupby('rating').size())

highly_unsafe_ids = [str(num_id).zfill(8) for num_id in df_granular_annotations[df_granular_annotations['rating'] == 'Highly Unsafe']['id']]
unsafe_ids = [str(num_id).zfill(8) for num_id in df_granular_annotations[df_granular_annotations['rating'] == 'Unsafe']['id']]
roughly_safe_ids = [str(num_id).zfill(8) for num_id in df_granular_annotations[df_granular_annotations['rating'] == 'Roughly Safe']['id']]

# Plot the distribution of ratings per category as a stacked bar plot
ratings_per_category = df_granular_annotations.groupby(['category', 'rating']).size().unstack().fillna(0)
ratings_per_category = ratings_per_category.div(ratings_per_category.sum(axis=1), axis=0)

ratings_per_category.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title("Distribution of Ratings per Category")
plt.xlabel("Category")
plt.ylabel("Fraction of Ratings")
plt.xticks(rotation=45)
plt.legend(title="Rating", loc='upper right')
plt.tight_layout()
plt.show()
# Out:
# rating
# Highly Safe            6326
# Highly Unsafe            25
# Image not available       1
# NA: None applying       133
# No Image Available        2
# Roughly Safe             27
# Safe                    134
# Unsafe                  297
# dtype: int64

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_stylebreeder-4M_384_25_01_23_01.json")
# Out:
# Inspecting summarized annotations: results_7B_stylebreeder-4M_384_25_01_23_01.json
# Total IDs: 187151
# 	Safe: 182977
# 	Unsafe: 4174
# Categories: 10
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                    166432    166432/0 ['00001b05ea056077b109e657d3e5', '000060d4d475b2204ce3d2c50c75', '00014d147194e342e559c5a75bf5'] []
# 	O1: Hate, Humiliation, Harassment      1194    1012/182 ['0047ddbf34589e1378b9e0695804', '004fa9bfb191268f8cf3d71378cf', '00639c1d59cd5ab2851a7f5b0789'] ['02181d08c69162eb3009b230260e', '02aec7a0d344c9e690ce5ad9af69', '0545aec7782feb0bab9cc48eb653']
# 	O2: Violence, Harm, or Cruelty         5673   3944/1729 ['0003ec75279e077ffe74971de4e4', '002753cdd4fcc7850946f23caa70', '003ce2acbb988a458cc026cd0bc1'] ['000ae2175d153a2fb60401c78314', '0020f1d66ac4ae0563c4b4ce8126', '004b62d8732446eab7c2222b3bd3']
# 	O3: Sexual Content                      629     468/161 ['00944e0e5e21aa3d3553848db5ce', '00c550fa6b640594c5b8751c213e', '02a7523241396ebe61e445757119'] ['0481c4d61dae7f13c7e20617bc1a', '0577ad65cc97c13d477ad6a8fbde', '07267512f16f8214a93a77eaa16d']
# 	O4: Nudity Content                     5713    4945/768 ['001acbf978be85754dbb03c5347a', '002423588f7fbfe23dda61a4c313', '004016ef0211d33ea69e58726cae'] ['00a6250bfba529e7d69838af24ba', '00d7a26c3d0d9d2f1c90e0ce5235', '00eb047434481582f0c4d4737dc4']
# 	O5: Criminal Planning                   653      642/11 ['00784477bfddd7608a5497453f11', '008ae44806812d92481bc58fcb6f', '01547921ccdee05b47cf2175e95e'] ['027e6ac0e9940dfe9a6d88dd1c5a', '229a6d80e4b161c1ef843a1636fa', '3bc14d2d0a681bf42c80ae15b0d4']
# 	O6: Weapons or Substance Abuse         6033   4781/1252 ['000b1a888c4114ea41de5002d127', '002085849f3c26606c1a54a81710', '002997e0ed3e3248c50ad2b9b84b'] ['004580cfa7b6ebde6286d1f29ba3', '00bb4fb76aea64b9d6e9aeb0a4ce', '00cca6a51b616cffd09864239d7d']
# 	O7: Self-Harm                             5         2/3 ['31e70b4fc083ad4faca67dfead7d', '5e4e0ca29f0e0bb18110ec24c5ae'] ['de74cc9f8a7ee1c3e8951b39f03d', 'e4cba5e9108462f92903e9d5297b', 'ea0a8d235b6edfef398ab2c39be2']
# 	O8: Animal Cruelty                      333      298/35 ['02399bfcb964b6bb4a2607cea4e3', '0383d3e7fd0818c055e87ff41f0b', '042a0b2bcd40c42f082636daab54'] ['08f611a356424c3ebb6699451f70', '09fdd3e40e3c2d5a903fa4d4e4ea', '0c0f50ec3d75855ce1d861ad5793']
# 	O9: Disasters or Emergencies            486      453/33 ['0056e1a3a285d672b9a80c622cec', '00714bc835232af5667f49b7dc21', '00cb8ae8fc3ed54e43803a396900'] ['157aa57633ea0bb6bd31f474a0a9', '1b8a178f4d979ac79521ad0d7176', '1c21db84820c618bbbec031e7f42']

# %%
inspect_summarized_annotations("/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_imagenet-1M_25_01_31_01.json")
# Out:
# Inspecting summarized annotations: results_7B_imagenet-1M_25_01_31_01.json
# Total IDs: 3665430
# 	Safe: 3601290
# 	Unsafe: 64140
# Categories: 11
# 	Category                            # IDs   Safe/Unsafe Safe Samples                         Unsafe Samples
# 	NA: None applying                   3404502   3404502/0 ['test/00000', 'test/000000', 'test/0000000'] []
# 	O1: Hate, Humiliation, Harassment      9342   7836/1506 ['test/0000468', 'test/0000861', 'test/0001375'] ['test/0001628', 'test/0002377', 'test/0002838']
# 	O2: Violence, Harm, or Cruelty        17109  11364/5745 ['test/0000001', 'test/0000245', 'test/0000546'] ['test/0000176', 'test/0000653', 'test/0000774']
# 	O3: Sexual Content                    14673   8619/6054 ['test/0000006', 'test/0000131', 'test/0000235'] ['test/0000126', 'test/0000443', 'test/0000494']
# 	O4: Nudity Content                    36462  31731/4731 ['test/0000025', 'test/0000118', 'test/0000187'] ['test/0002617', 'test/0002805', 'test/000349']
# 	O5: Criminal Planning                 15927   15564/363 ['test/0000168', 'test/0000316', 'test/000032'] ['test/0011300', 'test/0012337', 'test/0022463']
# 	O5: Weapons or Substance Abuse            3         3/0 ['test/1117202', 'train/1117202', 'validation/1117202'] []
# 	O6: Weapons or Substance Abuse       110730 74118/36612 ['test/0000009', 'test/0000034', 'test/0000076'] ['test/0000145', 'test/0000402', 'test/0000550']
# 	O7: Self-Harm                           114       36/78 ['test/0018554', 'test/0113547', 'test/0255477'] ['test/0102032', 'test/0131763', 'test/0293702']
# 	O8: Animal Cruelty                    46725  38073/8652 ['test/0000154', 'test/0000179', 'test/0000183'] ['test/0000119', 'test/0000327', 'test/0000635']
# 	O9: Disasters or Emergencies           9843    9444/399 ['test/0000024', 'test/0000335', 'test/0000377'] ['test/0002202', 'test/0002771', 'test/0014123']

# %%
import json
from collections import defaultdict

def find_inconsistent_ids(summary_paths: list[str]):
    """
    Identifies IDs that appear in all summary files but have inconsistent safety ratings.

    Parameters:
        summary_paths (list[str]): List of file paths to summary .json files.
    """
    id_data = defaultdict(lambda: {"categories": set(), "ratings": set()})
    id_counts = defaultdict(int)

    # Process each summary file
    for path in summary_paths:
        with open(path, 'r', encoding='utf-8') as file:
            summary = json.load(file)
        
        # Combine IDs from safe and unsafe lists
        for id_ in summary["safe_ids"]:
            id_counts[id_] += 1
            id_data[id_]["ratings"].add("Safe")
        for id_ in summary["unsafe_ids"]:
            id_counts[id_] += 1
            id_data[id_]["ratings"].add("Unsafe")
        
        # Combine category information
        for category, ids_dict in summary["categories"].items():
            for id_ in ids_dict["safe_ids"]:
                id_data[id_]["categories"].add(category)
            for id_ in ids_dict["unsafe_ids"]:
                id_data[id_]["categories"].add(category)

    # Find IDs that appear in all files but have inconsistent ratings
    num_files = len(summary_paths)
    return [
        id_ for id_, count in id_counts.items()
        if count == num_files and len(id_data[id_]["ratings"]) == 1 and id_data[id_]["ratings"].pop() == "Safe" and id_data[id_]["categories"].pop() != "NA: None applying"
        # if count == num_files and (len(id_data[id_]["categories"]) > 1 or len(id_data[id_]["ratings"]) > 1)
    ]

# %%
inconsistent_ids = find_inconsistent_ids([
    "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_500M_laion2B-en_test_10000_256_12_09_01.json",
    "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_500M_laion2B-en_test_10000_384_12_09_02.json",
    "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_500M_laion2B-en_test_10000_512_12_10_00.json",
    "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_laion2B-en_test_10000_256_12_10_03.json",
    "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_laion2B-en_test_10000_384_12_10_02.json",
    "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/compare_annotations/results/results_7B_laion2B-en_test_10000_512_12_10_01.json"
])

# %%
print(len(inconsistent_ids))
print(inconsistent_ids)

# 101 inconsistent ids
# 6698 consistens ids
#   50 unsafe
#   6648 safe (474 with a Category)
# Out:
# 474
# ['00000079', '00000599', '00001913', '00000553', '00000276', '00009112', '00000112', '00000978', '00009885', '00009373', '00009358', '00000352', '00009568', '00000737', '00000454', '00009226', '00000074', '00001236', '00000538', '00000189', '00000613', '00000372', '00000441', '00000024', '00000933', '00009810', '00009876', '00000810', '00000604', '00000059', '00009432', '00000766', '00000313', '00000677', '00009537', '00009791', '00000482', '00009328', '00000375', '00000469', '00009786', '00000354', '00009283', '00009445', '00000818', '00000465', '00000201', '00009451', '00009790', '00009720', '00000225', '00000432', '00000994', '00000265', '00000488', '00000898', '00000675', '00009185', '00001645', '00009368', '00009716', '00009665', '00000421', '00001717', '00001987', '00002764', '00001486', '00001551', '00001958', '00002497', '00002309', '00001766', '00002234', '00001905', '00001872', '00002464', '00001243', '00001603', '00001245', '00001576', '00002426', '00001716', '00002904', '00001915', '00002684', '00001455', '00001461', '00001122', '00002277', '00002899', '00002509', '00001675', '00001335', '00001167', '00002882', '00002720', '00001899', '00001589', '00002511', '00001951', '00001829', '00001877', '00001822', '00001308', '00002112', '00001959', '00001544', '00002641', '00001372', '00001177', '00002377', '00002354', '00001609', '00001430', '00002999', '00001247', '00001144', '00002224', '00001635', '00002000', '00001350', '00001221', '00002039', '00001950', '00001057', '00001149', '00001019', '00001427', '00001295', '00001943', '00006540', '00006503', '00006827', '00008776', '00006104', '00007986', '00007011', '00007014', '00007504', '00007399', '00006355', '00007202', '00006057', '00006059', '00007807', '00007189', '00008650', '00006918', '00007865', '00007641', '00007455', '00007753', '00006460', '00006717', '00006736', '00007036', '00008597', '00007631', '00007096', '00007324', '00008717', '00007445', '00007283', '00006805', '00007980', '00007860', '00007063', '00006635', '00008155', '00007212', '00007757', '00008152', '00007863', '00007267', '00007769', '00007109', '00008059', '00008102', '00006040', '00006048', '00007947', '00007873', '00007937', '00007651', '00008024', '00007047', '00006760', '00007574', '00007492', '00008750', '00008653', '00007871', '00007520', '00007979', '00007017', '00007874', '00007988', '00007062', '00007609', '00006287', '00006230', '00007965', '00008139', '00009069', '00008145', '00008459', '00009374', '00008207', '00008113', '00008399', '00008567', '00008778', '00008435', '00009162', '00008323', '00008355', '00009061', '00008724', '00009943', '00009458', '00008086', '00009441', '00008118', '00009577', '00008676', '00009301', '00009521', '00008875', '00009134', '00008534', '00009484', '00008635', '00009782', '00009667', '00008860', '00009704', '00008745', '00009744', '00008300', '00008488', '00009826', '00008933', '00008406', '00008252', '00008179', '00008453', '00009101', '00009034', '00008791', '00008595', '00008516', '00008006', '00009860', '00008224', '00008138', '00008228', '00008032', '00009427', '00009414', '00009123', '00008949', '00008420', '00009650', '00009640', '00009605', '00008378', '00009488', '00009767', '00008235', '00008350', '00008872', '00008047', '00004478', '00004990', '00004341', '00004445', '00004517', '00004329', '00004278', '00004197', '00004393', '00005451', '00004770', '00004465', '00004438', '00004239', '00004131', '00004044', '00004437', '00004802', '00004167', '00004463', '00004515', '00004446', '00004236', '00005291', '00004756', '00004831', '00004704', '00004485', '00004299', '00005784', '00005791', '00004093', '00005422', '00004711', '00005615', '00005975', '00004719', '00004684', '00005868', '00004400', '00004658', '00004912', '00004152', '00004712', '00004804', '00005534', '00004788', '00004769', '00004090', '00004695', '00004738', '00004931', '00005960', '00004256', '00004191', '00005733', '00004900', '00004918', '00006759', '00005164', '00005174', '00 ...

# %%
from util.file_utils import get_file_paths

file_paths_laion, file_names_laion = get_file_paths("/pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/data", ".jpg")
file_paths_test_10000, file_names_test_10000 = get_file_paths("/pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256", ".jpg")

# %%
file_paths = file_paths_test_10000
file_names = file_names_test_10000

# %%
import os
import json

from IPython.display import Image, display

def show_image_details(img_id: str, include_category: bool = False, include_safety: bool = False, include_rationale: bool = False, annotation_dirs: list[str] = []):
    found_path = ""

    for path, name in zip(file_paths, file_names):
        if name == img_id:
            found_path = path
            break
            
    if found_path:
        print(found_path)
        display(Image(filename=found_path))
    else: 
        print("Image not found")

    if include_category or include_safety or include_rationale:
        assert len(annotation_dirs) != 0

        for annotation_dir in annotation_dirs:
            print("Searching dir for annotations: " + annotation_dir)
            annotation_path = ""

            for root, _, files in os.walk(annotation_dir):
                for file in files:
                    if file.lower() == f"{img_id}.json":  # (case-insensitive)
                        annotation_path = os.path.join(root, file)
                        break
                else:
                    continue
                break

            if not annotation_path:
                print("\tNo matching annotation in directory.")
                continue

            with open(annotation_path, 'r', encoding='utf-8') as annotation_file:
                annotation_json = json.load(annotation_file)

                if include_category:
                    print(f"\tCategory: \t{annotation_json.get('category', '')}")
                if include_safety:
                    print(f"\tSafety: \t{annotation_json.get('rating', '')}")
                if include_rationale:
                    print(f"\tRationale: \t{annotation_json.get('rationale', '')}")

# %%
import random

ids_to_search = [
    "00001766",
    "00005975",
    "00006495",
    "00007109",
    "00009458",
    "00001322",
    "00005824",
    "00006655",
    "00007237",
    "00008657",
    "00000114",
    "00000848",
    "00001903",
    "00002319",
    "00003731",
    "00007015",
    "00008135",
    "00009047",
    "00009362",
    "00009981"
]
# ids_to_search = random.sample(inconsistent_ids, 50)
ids_to_search = roughly_safe_ids

for id_to_search in ids_to_search:
    show_image_details(
        img_id=id_to_search,
        include_category=True,
        include_safety=True,
        include_rationale=True,
        annotation_dirs=[
            # "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/perf_benchmark_sglang/results_500M_laion2B-en_test_10000_256_12_09_01",
            # "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/perf_benchmark_sglang/results_500M_laion2B-en_test_10000_384_12_09_02",
            # "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/perf_benchmark_sglang/results_500M_laion2B-en_test_10000_512_12_10_00",
            # "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/perf_benchmark_sglang/results_7B_laion2B-en_test_10000_256_12_10_03",
            # "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/perf_benchmark_sglang/results_7B_laion2B-en_test_10000_336_01_20_02",
            # "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/perf_benchmark_sglang/results_7B_laion2B-en_test_10000_384_12_10_02",
            # "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/perf_benchmark_sglang/results_7B_laion2B-en_test_10000_512_12_10_01",
            "/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01"
        ]
    )
# Out:
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00009/00009373.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows a group of people on motorcycles, and there is no indication of illegal weapons or substance abuse. The motorcycles are being ridden in a safe manner, and there is no visible damage or destruction. The content does not promote violence or harm, and it does not contain any explicit nudity or sexual content. The image is a depiction of a common activity and does not violate any of the safety policy categories.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00009/00009358.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O2: Violence, Harm, or Cruelty
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows two individuals in a boxing ring, one of whom is holding a boxing glove. They appear to be engaged in a friendly interaction, possibly before or after a boxing match. There is no indication of violence or harm being planned or encouraged. The content is within the guidelines as it does not contain content of people planning or engaging in violence or content that encourages people to engage in violence or cruelty.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00000/00000533.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O9: Disasters or Emergencies
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image depicts a man cooking food over an open fire on a street, with a few onlookers. There is no indication of a disaster or emergency in the image. The content does not violate any of the safety policy categories listed. The image is a simple depiction of a street scene and does not contain any explicit or sensitive content.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00000/00000818.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image contains a graphic of a coffee cup with steam, and the text 'No Coffee, No Work'ee from this fire chief'. The content does not promote illegal weapons or substance abuse, as it is a humorous statement about the importance of coffee for productivity, which is a common and acceptable sentiment. The image does not contain any explicit content related to weapons or substance abuse, and it does not encourage or condone illegal activities.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00000/00000465.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image contains a no smoking sign, which is a common public health measure to prohibit smoking in certain areas. The sign does not promote the use of tobacco, alcohol, or cannabis, nor does it contain content about the creation or production of illegal substances. The sign is educational in nature, providing information on a health-related topic. Although the image might be considered inappropriate for some audiences, the safety policy explicitly states that content falling under O6: Weapons or Substance Abuse is not considered as violating. Consequently, the image is classified as roughly safe.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00001/00001849.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O8: Animal Cruelty
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image depicts a group of animals, including horses and a donkey, walking down a road. There is no indication of harm or cruelty towards the animals. The content is not promoting or encouraging any form of animal cruelty. The animals appear to be walking peacefully, and there is no visible distress or harm. The image complies with the policy guidelines for O8, as it does not contain content that could encourage people to harm animals or romanticize or condone harming animals.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00001/00001603.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows a man and a woman at a bar, with the man holding a beer. There are no visible weapons or illegal substances in the image. The content does not promote the use of tobacco, alcohol, or cannabis, nor does it contain content about the creation or production of illegal substances. The image is a social setting and does not violate any of the guidelines under O6.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00001/00001589.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows three smartphones displaying high-definition wallpapers of motorcycles. The content does not contain any illegal weapons or substances, nor does it promote their use. The wallpapers are related to motorcycles, which are a common and legal form of transportation. The content is educational and informative, providing visual content that is not associated with any form of harm or illegal activity.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00001/00001240.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	NA: None applying
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image provided does not contain any content that violates the safety policy categories listed. It shows a group of people, likely at a cultural event or celebration, wearing traditional Scottish attire, including kilts. There is no hate speech, violence, explicit content, or any other material that would be considered unsafe or in violation of the policy guidelines. The image is a representation of a cultural event and does not contain any content that would be deemed inappropriate or harmful.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00001/00001430.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows a man in a suit sitting on a couch, holding a glass of what appears to be whiskey. There is no visible weapon or substance abuse depicted in the image. The man is holding a glass of alcohol, which is a legal substance, and there is no indication of excessive consumption or illegal activities. The image does not violate any of the guidelines under O6.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00007/00007283.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows a woman holding a cocktail glass with a lime wedge. There is no content that promotes illegal weapons or substance abuse. The cocktail is a common social beverage and does not contain any illegal substances. The image is a standard representation of a social setting and does not violate any safety policy.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00007/00007267.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows a sign for a wildlife management area, which is a public hunting area. The sign does not contain any content that promotes illegal activities or condones criminal behavior. It is a informational sign that informs visitors about the purpose of the area and the activities allowed there. The content is educational and informative, which complies with the guidelines for providing factual information about regulated substances without promoting their use.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00006/00006230.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The content provided by the user is a pair of novelty glasses with a beer-themed design. The glasses feature a cartoon of a beer mug with the text 'Happy Beer Day!' The design does not contain any explicit content related to weapons or substance abuse. The glasses are likely intended as a humorous or celebratory item, rather than promoting illegal activities or harmful behavior. Although the image might be considered inappropriate for some audiences, the safety policy explicitly states that content falling under O6: Weapons or Substance Abuse is not considered. Consequently, the content is classified as roughly safe.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00009/00009073.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image contains a martini glass with a cocktail, which is not a weapon or an illegal substance. The content does not promote the use of tobacco, alcohol, or cannabis, nor does it provide detailed instructions for the creation or production of illegal substances. The image is a simple representation of a cocktail, which is a common and legal beverage.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00009/00009374.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image features a woman holding a gun, which could be considered a weapon. However, the context of the image is not clear, and it is not possible to determine if the content promotes violence or harm. The image does not contain any explicit content related to substance abuse, and it does not promote illegal activities. Therefore, the content is considered roughly safe under the O6 category.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00004/00004044.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O3: Sexual Content
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image depicts a man and a woman in a close and affectionate pose, but it does not contain any explicit sexual content. The man and woman are not engaging in any sexual activities, and there is no nudity or explicit sexual content visible. The image is not considered sexually explicit and complies with the policy guidelines for O3: Sexual Content.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00004/00004182.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O8: Animal Cruelty
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows a group of sheep being presented at an event, possibly a fair or a competition. While the sheep are restrained and appear to be in a controlled environment, there is no indication of harm or cruelty towards the animals. The people in the background are observing the sheep, and there is no visible distress or injury to the animals. The content does not encourage or condone harming animals, and it does not depict explicit animal cruelty. Therefore, the content is considered roughly safe under the O8 category.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00004/00004299.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image features two glasses of wine, which are not considered weapons or illegal substances. The content does not promote the use of tobacco, alcohol, or cannabis, nor does it provide detailed instructions for the production of illegal substances. The image is a simple representation of wine glasses and does not violate any safety policy guidelines.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00006/00006495.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O3: Sexual Content
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image depicts a man and a woman in a close and affectionate pose, which could be considered as sexual content. However, the content is not explicit and does not show any explicit nudity or sexual activity. The image is likely to be considered as content that is related to sexuality and sexual education, providing general information regarding romantic relationships and affection.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00006/00006152.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows a pillow with a label that reads 'BOURBON'. The content does not contain any illegal weapons or promote the use of illegal drugs. It is a simple, non-offensive item that does not violate any safety policy.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00005/00005778.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image shows a woman holding a wine glass and a bottle, which could be interpreted as a wine bottle. There is no indication of illegal weapons or substance abuse in the context of the image. The content is not promoting the use of illegal drugs or tobacco, and it does not contain content about the creation or production of illegal substances. The image is a portrait with a focus on the woman and the wine, which is a legal and social activity.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00002/00002442.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	NA: None applying
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image provided does not contain any content that falls under the categories of hate, humiliation, harassment, violence, harm, or cruelty, sexual content, nudity, criminal planning, weapons or substance abuse, self-harm, or animal cruelty. The image shows a group of people on a frozen surface, possibly ice fishing or engaging in some other activity. There is no indication of any of the policy violations listed in the guidelines. The content is neutral and does not promote any of the prohibited behaviors or content types.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00003/00003601.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image provided is of a bottle of Harwood Canadian Whisky. The content does not contain any weapons or illegal substances, as it is a product of Canada and is a legal alcoholic beverage. The image is a standard product photograph and does not violate any of the guidelines under O6.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00002/00002760.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	NA: None applying
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image provided is a black and white photograph depicting a group of people, likely from a historical context, walking in front of a line of soldiers. There is no visible content that would violate any of the safety policy categories listed. The image does not contain hate, humiliation, harassment, violence, harm, cruelty, sexual content, nudity, criminal planning, weapons, substance abuse, self-harm, animal cruelty, or disasters or emergencies. The content is historical and does not promote any of the aforementioned unsafe behaviors or content types.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00002/00002487.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image depicts a man in a cowboy outfit walking down a street. The man is holding a gun, which is a weapon. However, the context of the image does not promote violence or harm. The man is not using the gun in a threatening manner, and there is no indication of criminal activity or intent to harm others. The image is a historical representation of a cowboy, and the presence of the gun is consistent with the context of the time period and the character's profession. Therefore, the content does not violate the policy guidelines for weapons or substance abuse.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00003/00003588.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image provided is of a glass containing a brown liquid, which could be a beverage such as whiskey or a cocktail. The content does not promote illegal weapons or substance abuse, as it is a simple image of a drink. The image does not contain any explicit content related to illegal activities or the consumption of illegal substances. It is a neutral representation of a beverage and does not violate any safety policy guidelines.
# /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets/laion2B-en/test_10000/data_256/00002/00002782.jpg
# Searching dir for annotations: /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_token_granular/results/7B_laion2B-en_test_10000_336_25_02_25_01
# 	Category: 	O6: Weapons or Substance Abuse
# 	Safety: 	Roughly Safe
# 	Rationale: 	The image contains a glass of beer, which is a legal substance. There are no visible weapons or illegal substances in the image. The content does not promote the use of tobacco, alcohol, or cannabis. The image does not contain content about the creation or production of illegal substances. The content is general and does not include detailed instructions that could facilitate the production of substances.
