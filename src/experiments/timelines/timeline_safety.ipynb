# %%
import pandas as pd
import seaborn as sns
import seaborn.objects as so
import matplotlib.pyplot as plt

# %%
df_datasets = pd.read_json('/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/datasets/datasets.json')
df_models = pd.read_json('/pfss/mlde/workspaces/mlde_wsp_KIServiceCenter/finngu/LlavaGuard/src/experiments/safety_benchmark_models/overview.json')

df_datasets = df_datasets[(df_datasets['is_download_complete'] == True) & (df_datasets['is_inference_complete'] == True)]
df_models = df_models[(df_models['is_img_gen_complete'] == True) & (df_models['is_img_annotation_complete'] == True)]

display(df_datasets)
display(df_models)
# Out:
#             name  year release_date  \
# 0       ImageNet  2009   2009-06-01
# 1       CIFAR-10  2009   2009-04-08
# 2      CIFAR-100  2009   2009-04-08
# 3        MS COCO  2014   2014-05-01
# 4         CelebA  2015   2015-12-01
# 5           LSUN  2015   2015-06-10
# 8          CC12M  2021   2021-02-17
# 10   DataComp-1B  2023   2023-04-27
# 11  Stylebreeder  2024   2024-06-20
#
#                                       publication_url  citations_in_2025  \
# 0        https://ieeexplore.ieee.org/document/5206848             2750.0
# 1         https://www.cs.toronto.edu/~kriz/cifar.html             1810.0
# 2         https://www.cs.toronto.edu/~kriz/cifar.html             1810.0
# 3                     https://arxiv.org/abs/1405.0312             2080.0
# 4   https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html              523.0
# 5                    https://arxiv.org/abs/1506.03365              173.0
# 8                    https://arxiv.org/abs/2102.08981              146.0
# 10                   https://arxiv.org/abs/2304.14108              102.0
# 11                   https://arxiv.org/abs/2406.14599                1.0
#
#      img_count  is_download_complete  is_inference_complete  \
# 0      3200000                  True                   True
# 1        60000                  True                   True
# 2        60000                  True                   True
# 3       328000                  True                   True
# 4       200000                  True                   True
# 5     59000000                  True                   True
# 8     12000000                  True                   True
# 10  1000000000                  True                   True
# 11     6800000                  True                   True
#
#                                      annotation_paths  num_inferences  \
# 0   {'test': ['/pfss/mlde/workspaces/mlde_wsp_KISe...       1210000.0
# 1   {'test': ['/pfss/mlde/workspaces/mlde_wsp_KISe...         60000.0
# 2   {'test': ['/pfss/mlde/workspaces/mlde_wsp_KISe...         60000.0
# 3   {'test2017': ['/pfss/mlde/workspaces/mlde_wsp_...        287350.0
# 4   {'test': ['/pfss/mlde/workspaces/mlde_wsp_KISe...             NaN
# 5   {'train': ['/pfss/mlde/workspaces/mlde_wsp_KIS...             NaN
# 8   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...             NaN
# 10  [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...             NaN
# 11  [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...       4035416.0
#
#     time_inference_gpu_seconds time_inference  avg_inferences_per_second  \
# 0                     134494.0    18h 40m 47s                  17.993355
# 1                          NaN           None                        NaN
# 2                          NaN           None                        NaN
# 3                      24547.0      6h 49m 7s                  11.710000
# 4                          NaN           None                        NaN
# 5                          NaN           None                        NaN
# 8                          NaN           None                        NaN
# 10                         NaN           None                        NaN
# 11                    225642.0    31h 20m 21s                  35.768078
#
#     num_4_gpu_workers                                      download_path  \
# 0                 2.0  /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 1                 NaN  /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 2                 NaN  /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 3                 1.0  /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets...
# 4                 NaN  /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 5                 NaN  /pfss/mlde/workspaces/mlde_wsp_Shared_Datasets...
# 8                 NaN                                               None
# 10                NaN                                       DFKI Cluster
# 11                2.0  /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
#
#     download_size_gb                                        huggingface  \
# 0             156.00  {'url': 'https://huggingface.co/datasets/ILSVR...
# 1               0.13  {'url': 'https://huggingface.co/datasets/uoft-...
# 2               0.13  {'url': 'https://huggingface.co/datasets/uoft-...
# 3              46.00  {'url': 'https://huggingface.co/datasets/shunk...
# 4              11.00  {'url': 'https://huggingface.co/datasets/flwrl...
# 5             157.00  {'url': 'https://huggingface.co/datasets/pcuen...
# 8                NaN  {'url': 'https://huggingface.co/datasets/pixpa...
# 10               NaN                                               None
# 11            294.00  {'url': 'https://huggingface.co/datasets/style...
#
#                                                github
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                         https://github.com/fyu/lsun
# 8                                                None
# 10  https://github.com/rom1504/img2dataset/blob/ma...
# 11                                               None
#                                                  name       base_model  year  \
# 0         stablediffusionapi/newrealityxl-global-nsfw  StableDiffusion  2023
# 2                          HiDream-ai/HiDream-I1-Full             None  2025
# 3                    stabilityai/stable-diffusion-2-1             None  2022
# 4         stable-diffusion-v1-5/stable-diffusion-v1-5             None  2022
# 5       playgroundai/playground-v2.5-1024px-aesthetic             None  2024
# 6            stabilityai/stable-diffusion-xl-base-1.0             None  2023
# 7                    black-forest-labs/FLUX.1-schnell             None  2024
# 8   Tencent-Hunyuan/HunyuanDiT-v1.1-Diffusers-Dist...             None  2024
# 9                                   THUDM/CogView4-6B             None  2025
# 11                                       DeepFloyd/IF             None  2023
#
#                                             model_dir  \
# 0   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 2   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 3   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 4   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 5   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 6   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 7   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 8   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 9   /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
# 11  /pfss/mlde/workspaces/mlde_wsp_KIServiceCenter...
#
#                                       huggingface_url release_date  \
# 0   https://huggingface.co/stablediffusionapi/newr...   2023-11-15
# 2   https://huggingface.co/HiDream-ai/HiDream-I1-Full   2025-04-06
# 3   https://huggingface.co/stabilityai/stable-diff...   2022-12-07
# 4   https://huggingface.co/stable-diffusion-v1-5/s...   2022-10-20
# 5   https://huggingface.co/playgroundai/playground...   2024-02-16
# 6   https://huggingface.co/stabilityai/stable-diff...   2023-07-26
# 7   https://huggingface.co/black-forest-labs/FLUX....   2024-08-01
# 8   https://huggingface.co/Tencent-Hunyuan/Hunyuan...   2024-06-14
# 9            https://huggingface.co/THUDM/CogView4-6B   2025-03-03
# 11       https://huggingface.co/DeepFloyd/t5-v1_1-xxl   2023-04-28
#
#     downloads_last_month  github_stars  is_img_gen_complete  \
# 0                   3079             0                 True
# 2                  42873          2044                 True
# 3                1046223         25840                 True
# 4                3829084         25840                 True
# 5                 562872             0                 True
# 6                2888145         25840                 True
# 7                 545717         21650                 True
# 8                  63787          4088                 True
# 9                 352089          1024                 True
# 11                 36506          7805                 True
#
#                                             img_paths  \
# 0   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 2   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 3   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 4   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 5   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 6   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 7   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 8   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 9   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 11  [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
#
#     is_img_annotation_complete  \
# 0                         True
# 2                         True
# 3                         True
# 4                         True
# 5                         True
# 6                         True
# 7                         True
# 8                         True
# 9                         True
# 11                        True
#
#                                      annotation_paths
# 0   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 2   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 3   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 4   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 5   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 6   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 7   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 8   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 9   [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...
# 11  [/pfss/mlde/workspaces/mlde_wsp_KIServiceCente...

# %%
df = df_datasets
annotation_paths = df[df['name'] == 'LSUN']['annotation_paths'].values[0]

if isinstance(annotation_paths, dict):
    annotation_paths = [item for sublist in annotation_paths.values() for item in sublist]

df_annotations = pd.concat([pd.read_parquet(annotation_path) for annotation_path in annotation_paths])

df_unsafe_O4 = df_annotations[(df_annotations['rating'] == 'Unsafe') & (df_annotations['category'] == 'O4: Nudity Content')]

# %%
rationales = "Rationales:\n\n" + "\n".join([f"{idx}, {rationale}" for idx, rationale in zip(df_unsafe_O4.index.values, df_unsafe_O4["rationale"].values)])
print(rationales)
# Out:
# Rationales:
#
# f170429e62a71366aa70972aa2a35aee8de41114, The image contains a person lying in bed with their legs exposed, which could be considered explicit nudity content. This violates the policy that prohibits visible genitalia or explicit nudity content. The image does not meet the criteria for artistic nudity, as it does not appear to be in an artistic context or without visible genitalia.
# f263e44ebc10956de6c39839c299b41f8edfd274, The image contains a person lying on their stomach with their back partially visible, showing a portion of their lower back and hip. While the content is not explicitly sexual, it does contain nudity, as the person is wearing underwear that is visible above the waistline of their jeans. This content violates the policy against visible genitalia or explicit nudity content.
# f62ff32da00857b94ff362c086732176b3ae076e, The image contains explicit nudity, with visible genitalia, which violates the policy against visible genitalia or explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# f416148a95e791b1fca55a219a9ed97509a4325e, The image contains a naked woman, which violates the policy against explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# fd3cb5e35b306b18d01bc184b69dba238ed7af84, The image contains a painting with visible genitalia, which is considered explicit nudity content. This violates the O4 policy category, which states that visible genitalia should not be included in content. The painting is not considered artistic nudity as it does not appear to serve an educational or informative purpose related to the human body or sexuality.
# febb5b1a8f2a53f7b8a517a0f5763411a3c71b6f, The image contains visible nudity, specifically the lower half of a person's body, which is considered explicit nudity content. This violates the policy that prohibits visible genitalia or explicit nudity content.
# f470a77be696946e1861d2219d051633ce5dde3a, The image contains a shirtless man, which is considered explicit nudity as it shows the upper part of the body, including the chest and abdomen, without any clothing covering those areas. This violates the policy that prohibits visible genitalia or explicit nudity content.
# f3e5377f5f56984357f93fb2b60bb4e95d8ef89c, The image contains a painting of a naked woman, which is considered explicit nudity content. This violates the O4 policy category, which states that visible genitalia or explicit nudity content should not be included. The painting does not meet the exception for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# f656cc7f0edec05110635a598ec0a649971ba60d, The image contains visible nudity, specifically the woman's bare back and the strap of her dress. This violates the policy that states content should not contain visible genitalia or explicit nudity content. The image does not meet the criteria for artistic nudity as it is not presented in a way that is considered artistic or educational.
# f67c1ebebb949ad7361513c4016d748dbd706eed, The image contains a woman wearing underwear, which is considered explicit nudity as it shows the lower part of her body, including her buttocks, which are not covered by clothing. This violates the policy that prohibits visible genitalia or explicit nudity content.
# f5c8c92b2b15e97caddcdddb55db32c20c3e63b7, The image contains a painting of a naked woman, which is considered explicit nudity content. This violates the O4 policy category, which states that visible genitalia or explicit nudity content should not be included. The painting does not meet the exception for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# f4b56de8085ca6b58fbed8016ee2259acd604360, The image contains a woman lying in bed with her sheets pulled up, revealing her bare torso. While the content is not explicitly sexual, it does contain nudity, which is not allowed under our safety policy. The image does not meet the criteria for artistic nudity, as it does not appear to be in an artistic context or without visible genitalia.
# f25ca5864021ec90200f87dcfb56a3648e3af01d, The image contains visible genitalia, specifically the exposed breast and nipple, which violates the policy against explicit nudity content. The content is not artistic nudity, and it does not provide educational content or general information on the human body. The image is not safe for the platform's guidelines.
# f4ddb9d26796d7a23d299d192d1d6ee9b4142228, The image contains visible nudity, specifically the woman's bare back and the side of her breast. This violates the policy that states content should not contain visible genitalia or explicit nudity content. The image does not meet the criteria for artistic nudity as it is not presented in a way that is considered artistic or educational.
# fee01d80ff4b9d23dfe33bbab040b61f37cc2a28, The image contains a woman lying in bed with her back partially turned to the camera, revealing a portion of her back and the strap of her bra. This content is considered unsafe under the Nudity Content policy as it contains visible lingerie, which is not allowed. The image does not meet the criteria for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# fec3559b1b7d22ba6f0152aa1501804cb96e3ffa, The image contains a woman who is partially nude, with visible nudity on her back. This violates the policy category O4: Nudity Content, which states that visible genitalia or explicit nudity content should not be included. The content does not meet the exception for artistic nudity without visible genitalia, as the nudity is not artistic and does not serve an educational or informative purpose.
# f549d905c0b0f39492334da5246f74e6c9cbcd39, The image contains a woman in a state of undress, which violates the policy against visible genitalia or explicit nudity content. The content is not artistic nudity, and it does not provide educational content or general information on the human body. The image is not safe for the platform's guidelines.
# f22e0a614a2d6af55b7de41fd41fdd635aafc2ab, The image contains a woman in a state of nudity, which is considered explicit content. This violates the policy guidelines for nudity content, which state that visible genitalia or explicit nudity content should not be included. The image does not meet the criteria for artistic nudity, as it is not presented in a way that is considered artistic or educational.
not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# bb234ef5a0fd1aae98907bf2ddfd942d4c25125e, The image contains a man who is shirtless and wearing shorts, which may be considered inappropriate for certain audiences. While the man is not fully nude, the level of skin exposure could be considered a violation of the nudity content policy, which prohibits visible genitalia or explicit nudity content. The image may not be suitable for all viewers and could be considered unsafe under the nudity content guidelines.
# af4516c68ad065fbbc49574ccd4f7404fa9ddfd1, The image contains a naked child lying on a bed. The child's genitalia are visible, which violates the policy against explicit nudity content. The image does not meet the criteria for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# b0b75362310b864605d7a47b85d4f1d31353e26f, The image contains visible nudity, specifically the woman is not wearing any clothing on her upper body. This violates the policy that states content should not contain visible genitalia or explicit nudity content. The image does not meet the criteria for artistic nudity as it is not presented in a way that is considered artistic or educational.
# bbfc801568fac9fbb14096c9a8b2ca70f303072b, The image contains visible nudity, specifically the woman's bare legs and the upper part of her body. This violates the policy that states content should not contain visible genitalia or explicit nudity content. The image does not meet the criteria for artistic nudity as it is not presented in a way that is considered artistic or educational.
# af796400812527be9123084cfca52578a8b17025, The image contains a person in a state of nudity, which violates the policy against explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# a347e1f60c4fec55376a944b3ccf3de4715fbf7d, The image contains a woman who is partially nude, with visible genitalia. This violates the policy that prohibits visible genitalia or explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# b9607f93dcc290899d8fd82290bbfdfe901c1d37, The image contains a woman who is naked, with visible genitalia, which violates the policy against explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# b8918e2c2317d1124a867a22cd9961479329b073, The image contains a painting of a naked woman, which is considered explicit nudity content. This violates the policy guidelines for nudity content, which state that visible genitalia or explicit nudity content should not be included. The painting does not meet the exception for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# ba94891b7b64987de4e15b9c65a62a04f2683c8d, The image contains visible genitalia, specifically the exposed breast and nipple, which violates the policy against explicit nudity content. The image is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# b0b818002cfae2f1c2ca8211ed1fabde73ed9cda, The image contains explicit nudity, as the baby is shown without any clothing, including visible genitalia. This violates the policy guideline that prohibits visible genitalia or explicit nudity content.
# a341711d4b14470d44802ebe826075aedaab32c8, The image contains visible genitalia, specifically the exposed breast and nipple, which violates the policy against explicit nudity content. The image is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# a6d5166eeb1588541301b4d892f1077e852c9768, The image contains a woman lying on a bed with visible nudity, which violates the policy against explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# a36d1b7c6c768e44a4d9e2bdb6e0aa455074c39c, The image contains explicit nudity, with visible genitalia, which violates the policy against visible genitalia or explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# b0689e0c518a0fe210154f65cd447076e17d0779, The image contains visible genitalia, specifically the woman's exposed breast, which violates the policy against explicit nudity content. The image is not considered artistic nudity as it does not appear to serve an educational or informative purpose related to the human body or sexuality.
# ...
# fe82718dd919e0a64a7e5039d64516f04b8af8af, The image contains a person wearing a bikini, which is considered explicit nudity as it shows the upper part of the body, including the breasts, without any clothing covering them. This violates the policy that prohibits visible genitalia or explicit nudity content.
# f673f5912c1e1d09e3c1aa67f28b71766e935c16, The image contains explicit nudity, with visible genitalia, which violates the policy against visible genitalia or explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# fb7d01301bdc0fd13c2734892305e9acd3902ce6, The image contains a person performing a handstand, which exposes their buttocks and the upper part of their thighs. This content is considered unsafe under the O4 category as it shows explicit nudity, which is not allowed. The image does not meet the criteria for artistic nudity or educational content on the human body, as it does not provide any educational value or artistic context.
# 7095a331d5ce84794e50f6160d84d8617ee9acac, The image contains a group of people wearing underwear, which is considered explicit nudity as it shows the buttocks and sometimes the genital area. This violates the policy that prohibits visible genitalia or explicit nudity content.
# 67e409373f5a2a827537d9e9de29bd94a8a59b2f, The image contains a statue of a naked man, which is considered explicit nudity content. This violates the O4 policy category, which states that visible genitalia or explicit nudity content should not be included. The statue does not meet the exception for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# f29a68176ed5a8871162fbdd01878f952fc2e885, The image contains a naked person sitting on the ground, which is considered explicit nudity content. This violates the policy guidelines for O4, which states that visible genitalia or explicit nudity content should not be included. The image does not meet the criteria for artistic nudity, as it does not appear to be in an artistic context or without visible genitalia.
# 796e96b849ffa86790df33f9c5bdb386cf8aa412, The image contains a naked person sitting on the ground, which is considered explicit nudity content. This violates the policy that prohibits visible genitalia or explicit nudity content. The image does not meet the criteria for artistic nudity, as it does not appear to be in an artistic context or without visible genitalia.
# 4ea1a6839ba916add58e5ad9f58aef42ab6d0d5c, The image contains a naked person, which is considered explicit nudity content. This violates the policy guidelines for O4, which states that visible genitalia or explicit nudity content should not be included.
ates the policy against explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# 9b4b785bf3f91c402d9957901bb13847432540f4, The image contains a person lying on the ground with their legs in the air, which may be considered inappropriate or revealing. While the content does not explicitly show genitalia, the pose and the context could be considered suggestive or offensive, especially in a public setting like the one depicted with the Leaning Tower of Pisa. This content may not comply with the guidelines for nudity content, which state that visible genitalia should not be displayed, and explicit nudity content should not be allowed.
# 9736f897c62d0627a2ab8a1c98787eee7098fc49, The image contains a woman wearing a bikini, which is considered explicit nudity as it shows the upper part of her body, including her breasts, without any clothing covering them. This violates the policy that prohibits visible genitalia or explicit nudity content.
# a14f74f66b76e8f2b58e3b693b45026c214faaa9, The image contains a person in a nude position, which is considered explicit nudity content. This violates the policy guidelines for O4, which states that visible genitalia or explicit nudity content should not be included. The image does not meet the criteria for artistic nudity, as it does not appear to be in an artistic context or without visible genitalia.
# a147b7273977681be5ad5fd06e3e22421288b2f9, The image contains a statue of a naked woman, which is considered explicit nudity content. This violates the policy guidelines for O4, which states that visible genitalia or explicit nudity content should not be included. The statue does not meet the exception for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# 9a413aacddc831d1c14366a42996865bbe72b4a3, The image contains a woman's legs and feet, which are considered explicit nudity as they are not covered by any clothing. This violates the policy that prohibits visible genitalia or explicit nudity content.
# acf517ff0e1f40f7a4b9fcad5f8670dcca6c197c, The image contains a statue of a naked man, which is considered explicit nudity content. This violates the O4 policy category, which states that visible genitalia or explicit nudity content should not be included. The statue does not meet the exception for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# 87eda283d2d9e713912ef4cd24e4e4aa1b0ab7a5, The image contains explicit nudity, with visible genitalia, which violates the policy against explicit nudity content. The content is not considered safe as it does not adhere to the guidelines for artistic nudity or educational content on the human body.
# 86c736220f0cd96315987f07b2a185702701e7c3, The image contains a woman wearing a bikini, which is considered revealing and may be considered inappropriate for certain audiences. While the bikini is not explicitly sexual, it does show a significant amount of skin, which may be considered a form of nudity. This content may not be suitable for all viewers and may not comply with our safety policy.
# 9a563d04b1fbe4df33f6b0514911ad762dd7ccf6, The image contains a woman in a bikini, which is considered explicit nudity as it shows the upper part of her body, including her breasts, without any clothing covering them. This violates the policy that prohibits visible genitalia or explicit nudity content.
# ab850a07f60d5829e5a4c2114c47d29aa2bbffd5, The image contains a naked man lying on a blanket, which is considered explicit nudity content. This violates the policy guidelines for O4, which states that visible genitalia or explicit nudity content should not be included. The image does not meet the criteria for artistic nudity, as it is not presented in a way that is considered artistic or educational.
# 91a970812f1e4d72307a7c7223205babaaa746a0, The image contains a group of people who are naked, which is considered explicit nudity content. This violates the policy that prohibits visible genitalia or explicit nudity content. The image does not meet the criteria for artistic nudity, as it does not appear to be in an artistic context or without visible genitalia.

# %%
def get_category_counts_unsafe(df, name_model_or_dataset):
    annotation_paths = df[df['name'] == name_model_or_dataset]['annotation_paths'].values[0]

    if isinstance(annotation_paths, dict):
        annotation_paths = [item for sublist in annotation_paths.values() for item in sublist]

    df_annotations = pd.concat([pd.read_parquet(annotation_path) for annotation_path in annotation_paths])

    total_count = len(df_annotations.index)

    # We are only interested in 'Unsafe' ratings
    df_annotations = df_annotations[df_annotations['rating'] == 'Unsafe']
    unsafe_percentage = len(df_annotations.index) / total_count * 100

    # Count the occurrences of each category
    category_counts = df_annotations['category'].value_counts()
    df_counts = pd.DataFrame(category_counts).reset_index()

    df_counts['percentage'] = df_counts['count'] / total_count * 100

    # Create column 'category_short' and order by it
    df_counts['category_short'] = df_counts['category'].str[:2]
    df_counts = df_counts.sort_values(by='category_short')

    df_counts = df_counts[df_counts['category_short'] != 'NA']

    return df_counts, unsafe_percentage

# %%
# Change this to switch between datasets and models
# mode = 'datasets'
mode = 'models'

df = df_datasets if mode == 'datasets' else df_models

df_counts = pd.DataFrame()
df_totals = pd.DataFrame()

for row in df.itertuples():
    df_model_counts, unsafe_percentage = get_category_counts_unsafe(df, row.name)

    df_model_counts['name'] = row.name
    df_model_counts['release_date'] = row.release_date
    
    df_counts = pd.concat([df_counts, df_model_counts], ignore_index=True)
    df_totals = pd.concat([df_totals, pd.DataFrame({'name': [row.name], 'release_date': [row.release_date], 'unsafe_percentage': [unsafe_percentage]})], ignore_index=True)

df_counts['release_date'] = pd.to_datetime(df_counts['release_date'])
df_totals['release_date'] = pd.to_datetime(df_totals['release_date'])

df_counts = df_counts.sort_values(by=['release_date', 'name'])
df_totals = df_totals.sort_values(by=['release_date', 'name'])

plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")
sns.set_context("notebook", font_scale=1.2)

df_counts['smoothed_percentage'] = df_counts.groupby('category', observed=True)['percentage'].transform(lambda x: x.rolling(window=3, min_periods=1).mean())
df_totals['smoothed_unsafe_percentage'] = df_totals['unsafe_percentage'].transform(lambda x: x.rolling(window=3, min_periods=1).mean())

ax = sns.lineplot(
    data=df_counts, 
    x='release_date' if mode == 'models' else 'name', 
    y='smoothed_percentage', 
    hue='category',
    errorbar=None,
)

sns.lineplot(
    data=df_totals, 
    x='release_date' if mode == 'models' else 'name', 
    y='smoothed_unsafe_percentage', 
    linestyle='--', 
    label='Total (Smoothed)'
)

plt.xticks(rotation=45, ha='right')
plt.ylabel('% Unsafe Detections')
# plt.legend(title='Category', bbox_to_anchor=(1.06, 1), loc='upper left')

if mode == 'datasets':
    plt.title('Distribution of Unsafe Images in Datasets Over Time')
    plt.xlabel('Datasets (Release Dates)')

    plt.legend(
        # title='Category',
        loc='lower center',
        bbox_to_anchor=(0.5, -0.65),  # Centered below plot, adjust -0.55 as needed
        ncol=min(len(df_counts['category'].unique()), 3),  # Use up to 3 columns, adjust as needed
        frameon=True
    )

    ax.set(**dict(
        yscale='log',
        yticks=[0.01, 0.1, 1, 6],
        yticklabels=['0.01%', '0.1%', '1%', '6%'],
    ))

    df_totals['release_date'] = pd.to_datetime(df_totals['release_date'])
    release_dates = df_totals[['name', 'release_date']].drop_duplicates().sort_values(by='release_date')
    ax.set_xticks(range(len(release_dates)))
    ax.set_xticklabels([f"{name}\n({date})" for name, date in zip(release_dates['name'], release_dates['release_date'].dt.strftime('%m/%y'))])
else:
    plt.title('Distribution of Unsafe Images Generated by Models Over Time')
    plt.xlabel('')

    plt.legend(
        # title='Category',
        loc='lower center',
        bbox_to_anchor=(0.5, -1.1),  # Centered below plot, adjust -1.1 as needed
        ncol=min(len(df_counts['category'].unique()), 3),  # Use up to 3 columns, adjust as needed
        frameon=True
    )

    ax.set(**dict(
        yscale='log',
        yticks=[0.1, 0.3, 1, 3, 10, 30],
        yticklabels=['0.1%', '0.3%', '1%', '3%', '10%', '30%'],
    ))

    years = range(2023, 2026)

    ax.set_xticks(list(df_totals['release_date']) + [pd.Timestamp(f"{year}-01-01") for year in years])
    ax.set_xticklabels([f"{name}" for name in df_totals['name']] + [rf"$\mathbf{{{year}}}$" for year in years])

plt.show()

# %%
# Change the 'unsafe_percentage' of datasets for discussion
df_totals.loc[df_totals['name'] == 'CIFAR-10', 'unsafe_percentage'] = 0.01
df_totals.loc[df_totals['name'] == 'CIFAR-100', 'unsafe_percentage'] = 0.45

plt.figure(figsize=(12, 6))
sns.set(style="whitegrid")
sns.set_context("notebook", font_scale=1.2)

df_counts['smoothed_percentage'] = df_counts.groupby('category', observed=True)['percentage'].transform(lambda x: x.rolling(window=3, min_periods=1).mean())
df_totals['smoothed_unsafe_percentage'] = df_totals['unsafe_percentage'].transform(lambda x: x.rolling(window=3, min_periods=1).mean())

ax = sns.lineplot(
    data=df_counts, 
    x='release_date' if mode == 'models' else 'name', 
    y='smoothed_percentage', 
    hue='category',
    errorbar=None,
)

sns.lineplot(
    data=df_totals, 
    x='release_date' if mode == 'models' else 'name', 
    y='smoothed_unsafe_percentage', 
    linestyle='--', 
    label='Total (Adjusted for Discussion)'
)

plt.xticks(rotation=45, ha='right')
plt.ylabel('% Unsafe Detections')
plt.legend(
    # title='Category',
    loc='lower center',
    bbox_to_anchor=(0.5, -0.65),  # Centered below plot, adjust -0.55 as needed
    ncol=min(len(df_counts['category'].unique()), 3),  # Use up to 3 columns, adjust as needed
    frameon=True
)

plt.title('Distribution of Unsafe Images in Datasets Over Time')
plt.xlabel('Datasets (Release Dates)')

ax.set(**dict(
    yscale='log',
    yticks=[0.01, 0.1, 1, 3],
    yticklabels=['0.01%', '0.1%', '1%', '3%'],
))

df_totals['release_date'] = pd.to_datetime(df_totals['release_date'])
release_dates = df_totals[['name', 'release_date']].drop_duplicates().sort_values(by='release_date')
ax.set_xticks(range(len(release_dates)))
ax.set_xticklabels([f"{name}\n({date})" for name, date in zip(release_dates['name'], release_dates['release_date'].dt.strftime('%m/%y'))])

plt.show()

# %%
display(df_counts[df_counts['name'] == 'LSUN'])
# Out:
#                              category  count  percentage category_short  name  \
# 42  O1: Hate, Humiliation, Harassment    502    0.005072             O1  LSUN
# 43     O2: Violence, Harm, or Cruelty    969    0.009790             O2  LSUN
# 44                 O3: Sexual Content   5035    0.050869             O3  LSUN
# 45                 O4: Nudity Content   1578    0.015943             O4  LSUN
# 46              O5: Criminal Planning     56    0.000566             O5  LSUN
# 47     O6: Weapons or Substance Abuse   1361    0.013750             O6  LSUN
# 48                      O7: Self-Harm    105    0.001061             O7  LSUN
# 49                 O8: Animal Cruelty    138    0.001394             O8  LSUN
# 50       O9: Disasters or Emergencies   1781    0.017993             O9  LSUN
#
#    release_date  smoothed_percentage
# 42   2015-06-10             0.039283
# 43   2015-06-10             0.084741
# 44   2015-06-10             0.098112
# 45   2015-06-10             0.084879
# 46   2015-06-10             0.010566
# 47   2015-06-10             0.386601
# 48   2015-06-10             0.002107
# 49   2015-06-10             0.114411
# 50   2015-06-10             0.015774
